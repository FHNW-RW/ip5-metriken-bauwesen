# %% [markdown]
# ## Analyse Hauptnutzfläche / Geschossfläche

# %%
from typing import Final

import seaborn as sns
import src.package.importer as im
import src.package.consts as c
import src.package.charts as charts
import src.package.importer_usages as imp_usg

FIELD: Final = c.FIELD_AREA_MAIN_USAGE
FIELD_RATIO: Final = c.FIELD_HNF_GF_RATIO
LABEL: Final = charts.LABEL_HNF
LABEL_RATIO: Final = charts.LABEL_RATIO_HNF_GF

charts.set_preferences(sns, font_scale=2)

df = im.get_extended_dataset('../../package/datasets/full_dataset.csv', cluster_threshold=10, hnf_gf_ratio=False)
df = im.calculate_gf_ratio(df, other_field=FIELD, ratio_field=FIELD_RATIO, cut_lower=0.0, cut_upper=1.0)
df, usages = imp_usg.extract_usage_details(df)
filtered_df = im.select_relevant_features(df)

# df = im.cap_upper_gf_field(df, upper_percentile='90%', field=FIELD)

# %% [markdown]
# ### Allgemein

# %%
filtered_df[FIELD].describe()
# Out:
# count      419.000000
# mean      3269.632458
# std       4310.445809
# min         75.000000
# 25%        719.500000
# 50%       1602.000000
# 75%       4049.500000
# max      29437.000000
# Name: area_main_usage, dtype: float64

# %%
filtered_df[c.FIELD_AREA_TOTAL_FLOOR_416].describe()
# Out:
# count      894.000000
# mean      6384.539150
# std       8584.172628
# min         50.000000
# 25%       1423.250000
# 50%       3420.500000
# 75%       7695.000000
# max      75328.000000
# Name: area_total_floor_416, dtype: float64

# %% [markdown]
# ### Visualisierungen
# Zeigt **Hauptnutzfläche** in relation zur **Geschossfläche**.

# %%
charts.lmplot_gf_field(filtered_df, field=FIELD, field_label=LABEL)

# %%
charts.regplot_gf_field(filtered_df, field=FIELD, field_label=LABEL, logscale=True)
# Out:
# <AxesSubplot:xlabel='Geschossfläche GF', ylabel='Hauptnutzfläche HNF'>

# %% [markdown]
# #### 75% Perzentil

# %%
df_75_percentile = im.cap_upper_gf_field(filtered_df)
charts.lmplot_gf_field(df_75_percentile, field=FIELD, field_label=LABEL, ratio_label=FIELD_RATIO, percentile='75')
# Out:
# /Users/lucadietiker/Documents/05_Projects/Python.nosync/ip5-metriken-bauwesen/src/package/importer.py:96: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   capped_df = capped_df[df[c.FIELD_AREA_TOTAL_FLOOR_416] <= gf_upper]

# %% [markdown]
# #### 25% Perzentil

# %%
df_25_percentile = im.cap_upper_gf_field(filtered_df, upper_percentile='25%')
charts.lmplot_gf_field(df_25_percentile, field=FIELD, field_label=LABEL, ratio_label=FIELD_RATIO, percentile='25')
# Out:
# /Users/lucadietiker/Documents/05_Projects/Python.nosync/ip5-metriken-bauwesen/src/package/importer.py:96: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   capped_df = capped_df[df[c.FIELD_AREA_TOTAL_FLOOR_416] <= gf_upper]

# %% [markdown]
# ### Nach Kategorie
# Ausgenommen: TECHNIK, GESUNDHEIT, OFFENE_BAUTEN

# %%
clusters_to_remove = ["TECHNIK", "GESUNDHEIT", "OFFENE_BAUTEN"]
df_75_percentile.drop(df_75_percentile[df_75_percentile[c.FIELD_USAGE_CLUSTER].isin(clusters_to_remove)].index, inplace=True)

charts.lmplot_clustered(df_75_percentile, y=FIELD, y_label=LABEL, ratio_label=FIELD_RATIO, save_label=f'{FIELD_RATIO}_75percentile')

# %% [markdown]
# ### Beschreibung

# %%
charts.describe_ratios(df, ratio_field=FIELD_RATIO)
# Out:
#                count      mean       std       min       25%       40%  \
# usage_cluster
# ANDERES         10.0  0.470960  0.130991  0.319575  0.363234  0.375004
# BEHERBERGUNG    29.0  0.543177  0.100335  0.344300  0.483703  0.516139
# BETRIEB         31.0  0.588681  0.214915  0.088281  0.502303  0.587304
# BUERO           39.0  0.508637  0.111978  0.311340  0.435128  0.473002
# GESUNDHEIT      10.0  0.452464  0.120911  0.284932  0.352116  0.423634
# HALLEN          42.0  0.660330  0.149470  0.353293  0.561818  0.605061
# KULTUS_KULTUR   11.0  0.622698  0.109693  0.461196  0.553277  0.560333
# SCHULEN        106.0  0.585648  0.104825  0.383370  0.514091  0.543682
# WOHNEN         122.0  0.545469  0.077008  0.354176  0.498238  0.518673
#
#                     50%       75%       max
# usage_cluster
# ANDERES        0.431123  0.607308  0.637772
# BEHERBERGUNG   0.543245  0.596336  0.806061
# BETRIEB        0.624879  0.741227  0.914773
# BUERO          0.488228  0.583956  0.765244
# GESUNDHEIT     0.463657  0.528969  0.642726
# HALLEN         0.643699  0.728445  0.979381
# KULTUS_KULTUR  0.598071  0.697885  0.793243
# SCHULEN        0.574546  0.640945  0.868280
# WOHNEN         0.541077  0.588057  0.859316

# %% [markdown]
# ### Violinplot
# Zeigt Ratios verschiedener Cluster inkl. Verteilung.<br>
# Unterteilung in umgekehrte Perzentile (also Grösser als).<br>

# %%
charts.set_preferences(sns, rc=[15, 8], font_scale=1.5)
charts.violinplot_ratios(df, ratio_field=FIELD_RATIO, ratio_label=LABEL_RATIO)

# %% [markdown]
# ## Benchmarks
# Benchmarks zu den Ratio – nach Cluster.<br>
#
# Ratios sind in **30%** der Fälle grösser als x

# %%
charts.set_preferences(sns, font_scale=2)

ratio_data = df[FIELD_RATIO]
charts.barplot_reversed_percentiles(ratio_data, df, ratio_field=FIELD_RATIO, ratio_label=LABEL_RATIO, percentile=70, upper_limit= 1.0, lower_limit=0.0)

# %% [markdown]
# Ratios sind in **60%** der Fälle grösser als x

# %%
charts.barplot_reversed_percentiles(ratio_data, df, ratio_field=FIELD_RATIO, ratio_label=LABEL_RATIO, percentile=40, upper_limit= 1.0, lower_limit=0.0)

# %% [markdown]
# Ratios sind in **70%** der Fälle grösser als x

# %%
charts.barplot_reversed_percentiles(ratio_data, df, ratio_field=FIELD_RATIO, ratio_label=LABEL_RATIO, percentile=30, upper_limit= 1.0, lower_limit=0.0)
