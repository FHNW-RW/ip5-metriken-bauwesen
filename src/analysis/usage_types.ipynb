# %% [markdown]
# ## Analyse Nutzung
# Überblick über die Nutzungsart der Gebäude

# %%
import pandas as pd
import src.package.charts as charts
import src.package.importer as im
import src.package.consts as c
import seaborn as sns
import matplotlib.pyplot as plt

# set size of seaborn plots
charts.set_plot_size(sns)

df = im.get_dataset('../package/dataset.csv')
pd.set_option('display.max_rows', 500)  # to show all value_counts

# %% [markdown]
# #### Verteilung im Datenset

# %%
df[c.FIELD_USAGE_CLUSTER].value_counts()
# Out:
# WOHNEN           300
# SCHULEN          194
# HALLEN            99
# BUERO             97
# BETRIEB           65
# BEHERBERGUNG      65
# GESUNDHEIT        32
# KULTUS_KULTUR     27
# ANDERES           15
# OFFENE_BAUTEN      9
# TECHNIK            9
# IRRELEVANT         8
# AUSSENANLAGEN      1
# Name: usage_cluster, dtype: int64

# %%
df[c.FIELD_NOM_USAGE_MAIN].value_counts()
# Out:
# WOHNBAUTEN__MFH_MEDIUM                                                                149
# SCHULBAUTEN__VOLKSSCHULEN                                                              99
# FREIZEITBAUTEN_SPORTBAUTEN_ERHOLUNGSBAUTEN__TURNHALLEN_SPORTHALLEN_MEHRZWECKHALLEN     49
# SCHULBAUTEN__KINDERGAERTEN_HORTE                                                       36
# WOHNBAUTEN__MFH_LOW                                                                    33
# WOHNBAUTEN__EFH_REIHEN_MEDIUM                                                          32
# WOHNBAUTEN__MFH_HIGH                                                                   31
# BUEROBAUTEN__VOLLAUSBAU                                                                29
# VERKEHRSBAUTEN__WERKHOEFE                                                              28
# VERWALTUNGSBAUTEN                                                                      23
# WOHNBAUTEN__ALTERSHEIME                                                                22
# SCHULBAUTEN__BERUFSSCHULEN                                                             21
# WOHNBAUTEN__EFH_REIHEN_HIGH                                                            20
# GESUNDHEIT__PFLEGEHEIME                                                                19
# SCHULBAUTEN__HOCHSCHULEN_UNIVERSITAETEN                                                16
# WOHNBAUTEN__EFH_REIHEN_LOW                                                             14
# BUEROBAUTEN__EDELROHBAU                                                                13
# LAGERBAUTEN_PRODUKTIONSBAUTEN                                                          13
# WOHNBAUTEN__ALTERSWOHNUNGEN                                                            11
# BUEROBAUTEN_VERWALTUNGSBAUTEN__GEMEINDEHAEUSER                                         10
# FREIZEITBAUTEN_SPORTBAUTEN__GARDEROBENGEBAEUDE                                          9
# WOHNBAUTEN__HEIMSTAETTEN_KINDERHEIME_JUGENDHEIME                                        9
# BANKEN                                                                                  8
# LANDWIRTSCHAFT__SCHEUNEN_STALLUNGEN                                                     8
# LAGERBAUTEN__INDUSTRIEHALLEN                                                            8
# GASTGEWERBE_FREMDENVERKEHRSBAUTEN__HOTELBAUTEN                                          7
# JUSTIZ__STRAFVOLLZUGSANSTALTEN                                                          7
# KULTUS__KIRCHGEMEINDEHAEUSER                                                            7
# WOHNBAUTEN__STUDENTENWOHNHAEUSER                                                        6
# GESUNDHEITSBAUTEN__KRANKENHAEUSER_Untersuchung                                          6
# SCHULBAUTEN__HEILPAEDAGOGISCHE_SONDERSCHULEN                                            5
# KULTUR__SAAL                                                                            5
# KULTUS__KIRCHE                                                                          5
# FREIZEITBAUTEN_SPORTBAUTEN__FREIBAD                                                     5
# SCHUTZBAUTEN__KASERNEN                                                                  5
# SCHUTZBAUTEN__SCHULUNGSBAUTEN                                                           4
# WOHNBAUTEN__TERRASSENHAEUSER_MEDIUM                                                     4
# LADENBAUTEN_HANDELSBAUTEN__EINZELHANDEL                                                 4
# VERKEHRSBAUTEN__ZOLL                                                                    4
# KULTUR__KULTUR_GEMEINSCHAFTSZENTREN                                                     4
# SCHUTZBAUTEN__FEUERWEHRGEBAEUDE                                                         4
# GESUNDHEITSBAUTEN__UNIVERSITAETSKLINIKEN_UNTERSUCHUNG                                   4
# GESUNDHEITSBAUTEN__TAGESHEIME                                                           4
# VERKEHRSBAUTEN__BAHNHOEFE                                                               4
# KULTUR__AUSSTELLUNGEN                                                                   3
# GASTGEWERBE_FREMDENVERKEHRSBAUTEN__RESTAURANT                                           3
# GASTGEWERBE_FREMDENVERKEHRSBAUTEN__HERBERGEN                                            3
# SCHULBAUTEN__FORSCHUNGSBAUTEN_OHNE_LABOR                                                3
# VERKEHRSBAUTEN__PARKHAEUSER_UNTERIRDISCH                                                3
# GASTGEWERBE_FREMDENVERKEHRSBAUTEN__SCHIRMHUETTEN                                        3
# VERKEHRSBAUTEN__STRASSENVERKEHR                                                         3
# VERKEHRSBAUTEN__POSTBETRIEBE                                                            3
# FREIZEITBAUTEN_SPORTBAUTEN__ZOO_TIERHAEUSER                                             3
# TECHNISCHE_ANLAGEN__UNTERWERK                                                           2
# LANDWIRTSCHAFT__SCHEUNEN                                                                2
# VERKEHRSBAUTEN__FLUGHAEFEN                                                              2
# WOHNBAUTEN__EFH_REIHEN_HIGHEST                                                          2
# FREIZEITBAUTEN_SPORTBAUTEN_ERHOLUNGSBAUTEN__PAVILLONS                                   2
# KULTUS__KREMATORIUM                                                                     2
# SCHUTZBAUTEN__AUSBILDUNGSZENTREN                                                        2
# LAGERBAUTEN_MEHRSTOECKIGE                                                               2
# TECHNISCHE_ANLAGEN__HEIZZENTRALE                                                        2
# KULTUR__MUSEEN                                                                          2
# KULTUR__KONGRESS                                                                        2
# SCHULBAUTEN__FORSCHUNGSBAUTEN_MIT_LABOR                                                 2
# LADENBAUTEN_HANDELSBAUTEN__MARKTHALLEN_UNBEHEIZT                                        2
# FREIZEITBAUTEN_SPORTBAUTEN__STADIONANLAGEN                                              2
# SCHULBAUTEN__BIBLIOTHEKEN                                                               2
# WOHNBAUTEN__TERRASSENHAEUSER_LOW                                                        2
# GESUNDHEITSBAUTEN__KRANKENHAEUSER_Logistik                                              2
# WOHNBAUTEN__TERRASSENHAEUSER_HIGHEST                                                    2
# JUSTIZ__GERICHT                                                                         2
# VERKEHRSBAUTEN__VERKEHRSPAVILLONS                                                       2
# VERKEHRSBAUTEN__EISENBAHN                                                               2
# JUSTIZ__POLIZEI                                                                         2
# LADENBAUTEN_VERWALTUNGSBAUTEN__RATHAEUSER                                               2
# VERKEHRSBAUTEN__UEBERDACHUNGEN                                                          1
# GESUNDHEITSBAUTEN__PFLEGE_REHA__PFLEGEHEIM                                              1
# LAGERBAUTEN__INDUSTRIEBAUTEN_GEWERBEBAUTEN__LAGERHALLEN_UNBEHEIZT                       1
# LANDWIRTSCHAFT__GEB_TIERHALTUNG_PRODUKTION__PRODUKTIONSANLAGE                           1
# VERKEHRSBAUTEN__BAHNBETRIEB                                                             1
# VERKEHRSBAUTEN__LUFT__FRACHTERMINAL                                                     1
# LANDWIRTSCHAFT__TIERSPITAELER                                                           1
# GASTGEWERBE_FREMDENVERKEHRSBAUTEN__KANTINEN                                             1
# FREIZEITBAUTEN_SPORTBAUTEN__SPORTPLAETZE                                                1
# VERKEHRSBAUTEN__WERKHOEFE__DIENSTRAUM                                                   1
# LAGERBAUTEN__SILOBAUTEN                                                                 1
# LADENBAUTEN_HANDELSBAUTEN__GROSSHANDEL                                                  1
# TECHNISCHE_ANLAGEN__SONDERABFALLSAMMELSTELLE                                            1
# TECHNISCHE_ANLAGEN__ABFALLBESEITIGUNG__ENTSORGUNGSANLAGE                                1
# LAGERBAUTEN__INDUSTRIEBAUTEN_GEWERBEBAUTEN__LAGERHALLEN_BEHEIZT                         1
# VERKEHRSBAUTEN__FLUG__VERWALTUNG                                                        1
# GESUNDHEITSBAUTEN__UNIVERSITAETSKLINIKEN_BETTENTRAKT                                    1
# SCHUTZBAUTEN__KASERNE_AUSBILDUNG__SCHULUNGSGEBAEUDE                                     1
# LAGERBAUTEN__VERTEILZENTRALEN_NONFOOD                                                   1
# VERKEHRSBAUTEN__SEILBAHNEN                                                              1
# GESUNDHEITSBAUTEN__UNIVERSITAETSKLINIKEN_FORSCHUNG                                      1
# VERKEHRSBAUTEN__ZOLL__ZOLLGEBAEUDE                                                      1
# FREIZEITBAUTEN_SPORTBAUTEN_ERHOLUNGSBAUTEN__GAERTEN_GEWAECHSHAEUSER                     1
# VERKEHRSBAUTEN__HOCH_TIEFGARAGE__TIEFGARAGE__PARKHAUS                                   1
# FREIZEITBAUTEN_SPORTBAUTEN__BOOTSHAEUSER                                                1
# KULTUS__KAPELLE                                                                         1
# FREIZEITBAUTEN_SPORTBAUTEN__FREIZEITZENTREN                                             1
# KULTUR__WOHLFAHRT                                                                       1
# WOHNBAUTEN__PERSONALHAEUSER                                                             1
# SCHUTZBAUTEN__SANITAET                                                                  1
# LADENBAUTEN_HANDELSBAUTEN__MARKTHALLEN                                                  1
# VERKEHRSBAUTEN__BUSBAHNHOF                                                              1
# GESUNDHEITSBAUTEN__KRANKENHAEUSER_BETTENTRAKT                                           1
# VERKEHRSBAUTEN__TANKSTELLE                                                              1
# GASTGEWERBE_FREMDENVERKEHRSBAUTEN__BEHERBERGUNGSSTAETTE__HOTEL                          1
# GASTGEWERBE_FREMDENVERKEHRSBAUTEN__RASTSTAETTEN                                         1
# VERKEHRSBAUTEN__BAHN__UEBERDACHUNG                                                      1
# SCHUTZBAUTEN__ZIVILSCHUTZANLAGEN                                                        1
# TECHNISCHE_ANLAGEN__KEHRICHTVERBRENNUNGSANLAGEN                                         1
# SCHULBAUTEN__BIBLIOTHEKEN__BIBLIOTHEK                                                   1
# GESUNDHEITSBAUTEN__KRANKENHAUS_SPITAL__ADMINISTRATION                                   1
# JUSTIZ__WIEDEREINGLIEDERUNGSSTAETTEN                                                    1
# FREIZEITBAUTEN_SPORTBAUTEN__HALLENBAEDER                                                1
# VERKEHRSBAUTEN__PARKHAEUSER_OBERIRDISCH                                                 1
# Name: nom_usage_main, dtype: int64

# %% [markdown]
# ## Nutzungen kombinieren
# Der Datensatz enthält sehr unterschiedliche Datenmengen pro Nutzungstyp. Wenn zu wenig Daten vorhanden sind, macht das Verwenden des Felds 'usage_cluster' oder weiteres Zusammenfassen Sinn. Für Nutzungstypen mit vielen Daten (Wohnen, Schulen etc.) macht es Sinn, ein spezifischeren Typ zu verwenden.
#
# **Mehrfamilienhäuser**<br>
# WOHNBAUTEN__MFH_MEDIUM<br>
# WOHNBAUTEN__MFH_LOW<br>
# WOHNBAUTEN__MFH_HIGH<br>

# %%
types_wohnen_mfh = ['WOHNBAUTEN__MFH_HIGH', 'WOHNBAUTEN__MFH_MEDIUM', 'WOHNBAUTEN__MFH_LOW']
mfh_df = df[df[c.FIELD_NOM_USAGE_MAIN].isin(types_wohnen_mfh)]

charts.lmplot_gf_hnf(mfh_df, hue=c.FIELD_NOM_USAGE_MAIN)

# %% [markdown]
# **Einfamilienhäuser**<br>
# WOHNBAUTEN__EFH_REIHEN_LOW<br>
# WOHNBAUTEN__EFH_REIHEN_MEDIUM<br>
# WOHNBAUTEN__EFH_REIHEN_HIGH

# %%
types_wohnen_efh = ['WOHNBAUTEN__EFH_REIHEN_LOW', 'WOHNBAUTEN__EFH_REIHEN_MEDIUM', 'WOHNBAUTEN__EFH_REIHEN_HIGH']
efh_df = df[df[c.FIELD_NOM_USAGE_MAIN].isin(types_wohnen_efh)]

charts.lmplot_gf_hnf(efh_df, hue=c.FIELD_NOM_USAGE_MAIN)

# %% [markdown]
# **Schulen sinnvoll aufteilen?**<br>
# SCHULBAUTEN__VOLKSSCHULEN<br>
# SCHULBAUTEN__KINDERGAERTEN_HORTE<br>
# SCHULBAUTEN__BERUFSSCHULEN<br>
# SCHULBAUTEN__HOCHSCHULEN_UNIVERSITAETEN<br>
# SCHULBAUTEN__FORSCHUNGSBAUTEN_MIT_LABOR<br>
# SCHULBAUTEN__BIBLIOTHEKEN<br>
# SCHULBAUTEN__FORSCHUNGSBAUTEN_OHNE_LABOR<br>
# SCHULBAUTEN__HEILPAEDAGOGISCHE_SONDERSCHULEN<br>

# %%
types_schulen = ['SCHULBAUTEN__VOLKSSCHULEN',
                 'SCHULBAUTEN__KINDERGAERTEN_HORTE',
                 'SCHULBAUTEN__BERUFSSCHULEN',
                 'SCHULBAUTEN__HOCHSCHULEN_UNIVERSITAETEN',
                 'SCHULBAUTEN__FORSCHUNGSBAUTEN_MIT_LABOR',
                 'SCHULBAUTEN__BIBLIOTHEKEN',
                 'SCHULBAUTEN__FORSCHUNGSBAUTEN_OHNE_LABOR',
                 'SCHULBAUTEN__HEILPAEDAGOGISCHE_SONDERSCHULEN'
                 ]
schulen_df = df[df[c.FIELD_NOM_USAGE_MAIN].isin(types_schulen)]

charts.lmplot_gf_hnf(schulen_df, hue=c.FIELD_NOM_USAGE_MAIN)

# %% [markdown]
# **Rest**<br>
# Vermutlich vorerst auf Usage Cluster zurückgreifen.

# %% [markdown]
# ## Ausreisser
# Ausreisser bei den Usage Clustern.
#
# 1) Description der verschiedenen Cluster. <br>
# 2) Ratio-Verteilung mit Ausreissern der verschiedenen Clustern – (Aussenanlagen, Betrieb, Offene Bauten und Irrelevant ausgeschlossen)<br>

# %%
# TODO: Uses SIA 416 only
mask = df[c.FIELD_USAGE_CLUSTER].isin(['TECHNIK', 'AUSSENANLAGEN', 'IRRELEVANT', 'OFFENE_BAUTEN'])
plotData = df[~mask]
gf = sns.catplot(x=c.FIELD_USAGE_CLUSTER, y="ratio_hnf_gf", kind="box", data=plotData)

gf.set(xlabel='Nutzungstyp (Cluster))', ylabel='Ratio HNF - GF')
plt.xticks(
    rotation=45,
    horizontalalignment='right',
    fontweight='normal',
    fontsize='medium'
)

# Check different cluster sizes
df[c.FIELD_USAGE_CLUSTER] = df[c.FIELD_USAGE_CLUSTER].astype('category')
# data = data[data[im.FIELD_USAGE_CLUSTER] == "BETRIEB"]
data = df[c.FIELD_HNF_GF_RATIO]
data.groupby(df[c.FIELD_USAGE_CLUSTER]).describe()
# Out:
#                count      mean       std       min       25%       50%  \
# usage_cluster
# ANDERES         10.0  0.470960  0.130991  0.319575  0.363234  0.431123
# AUSSENANLAGEN    1.0  0.602857       NaN  0.602857  0.602857  0.602857
# BEHERBERGUNG    32.0  0.539329  0.100309  0.344300  0.471030  0.539603
# BETRIEB         31.0  0.588681  0.214915  0.088281  0.502303  0.624879
# BUERO           40.0  0.508696  0.110534  0.311340  0.435179  0.491694
# GESUNDHEIT      12.0  0.513419  0.250111  0.284932  0.375928  0.463657
# HALLEN          42.0  0.660330  0.149470  0.353293  0.561818  0.643699
# IRRELEVANT       2.0  0.679538  0.222032  0.522538  0.601038  0.679538
# KULTUS_KULTUR   11.0  0.622698  0.109693  0.461196  0.553277  0.598071
# OFFENE_BAUTEN    3.0  0.519926  0.125502  0.386602  0.462002  0.537403
# SCHULEN        110.0  0.581099  0.107017  0.357656  0.513092  0.570817
# TECHNIK          3.0  0.459813  0.326410  0.255690  0.271583  0.287476
# WOHNEN         131.0  0.542463  0.076679  0.354176  0.495396  0.536050
#
#                     75%       max
# usage_cluster
# ANDERES        0.607308  0.637772
# AUSSENANLAGEN  0.602857  0.602857
# BEHERBERGUNG   0.597654  0.806061
# BETRIEB        0.741227  0.914773
# BUERO          0.573117  0.765244
# GESUNDHEIT     0.554460  1.226611
# HALLEN         0.728445  0.979381
# IRRELEVANT     0.758038  0.836538
# KULTUS_KULTUR  0.697885  0.793243
# OFFENE_BAUTEN  0.586589  0.635774
# SCHULEN        0.639369  0.868280
# TECHNIK        0.561874  0.836272
# WOHNEN         0.586987  0.859316
